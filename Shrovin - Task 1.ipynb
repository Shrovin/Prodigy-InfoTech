# %% [markdown]
# # Task 1

# %% [markdown]
# ## Adding the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Bad key text.latex.preview in file C:\Users\HP1\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file C:\Users\HP1\anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.5.3/matplotlibrc.template
# or from the matplotlib source distribution
#
# ...

# %% [markdown]
# ## Reading the data

# %%
df = pd.read_csv(r"C:\Users\HP1\OneDrive\Desktop\Task 1\worldpopulationdata.csv")

# %% [markdown]
# ## Checking top five data

# %%
df.head(5)
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %% [markdown]
# ## Checking the bottom five data

# %%
df.tail(5)
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %% [markdown]
# ## Checking out the columns

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# ## Information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df.describe(include="all")     #include = "all" will also show the value of the categorical variables
# Out:
#                                        Series Name        Series Code  \
# count                                         1085               1085
# unique                                           5                  5
# top     Population, female (% of total population)  SP.POP.TOTL.MA.ZS
# freq                                           217                217
# mean                                           NaN                NaN
# std                                            NaN                NaN
# min                                            NaN                NaN
# 25%                                            NaN                NaN
# 50%                                            NaN                NaN
# 75%                                            NaN                NaN
# max                                            NaN                NaN
#
#                      Country Name Country Code          2022          2021  \
# ...

# %% [markdown]
# ## Checking out the duplicates and the missing value in the dataset

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1080    False
# 1081    False
# 1082    False
# 1083    False
# 1084    False
# Length: 1085, dtype: bool

# %%
df.isnull().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# ## Finding out the unique values

# %%
print(df["Country Name"].unique())
print("\n Total number of unique country name:",df["Country Name"].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df["Country Code"].unique())
print("\n Total number of unique country code:",df["Country Code"].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['Series Name','Country Name'],axis=1,inplace=True)

# %% [markdown]
# ## Extraction of top ten countries with respect to total population

# %%
#Filter data for total population
total_population_data=df[df['Series Code']=='SP.POP.TOTL']

#sort data based on total population for 2022
total_population_sorted = total_population_data.sort_values(by="2022",ascending=False)

#Get the top ten countries with highest total number of population for 2022
total_top_ten_countries=total_population_sorted.head(10)
print("Top ten countries of total population\n")
print(total_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 89           IND
# 41           CHN
# 206          USA
# 90           IDN
# 149          PAK
# 144          NGA
# 26           BRA
# 15           BGD
# 161          RUS
# 127          MEX

# %% [markdown]
# ## Bar plot

# %% [markdown]
# ## Top ten countries of total population in the year 2022 and 2012

# %%
# create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(data=total_top_ten_countries,x='2022',y='Country Code',palette ="coolwarm")
plt.title("Top ten countries of total population of 2022", fontsize=10)
plt.xlabel('Total population',fontsize=10)
plt.xlabel('Country',fontsize=10)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(data=total_top_ten_countries,x='2012',y='Country Code',palette ="coolwarm")
plt.title("Top ten countries of total population of 2012", fontsize=10)
plt.xlabel('Total population',fontsize=10)
plt.xlabel('Country',fontsize=10)
plt.show()

# %% [markdown]
# ## Extraction of bottom ten countries with respect to total population

# %%
# filter data
total_population_data_1=df[df['Series Code']=='SP.POP.TOTL']

total_sorted_population=total_population_data_1.sort_values(by='2022',ascending=True)

#Get the top ten countries with highest total number of population for 2022
total_bottom_ten_countries=total_sorted_population.head(10)
print("Top ten countries of total population\n")
print(total_bottom_ten_countries[['Country Code']])
# Out:
# Top ten countries of total population
#
#     Country Code
# 201          TUV
# 137          NRU
# 150          PLW
# 27           VGB
# 183          MAF
# 75           GIB
# 164          SMR
# 130          MCO
# 114          LIE
# 124          MHL

# %% [markdown]
# ## Top ten countries of total population in the year 2022 and 2012

# %%
# create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(data=total_bottom_ten_countries,x='2022',y='Country Code',palette ="Accent")
plt.title("Bottom ten countries of total population of 2022", fontsize=10)
plt.xlabel('Total population',fontsize=10)
plt.xlabel('Country',fontsize=10)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(data=total_bottom_ten_countries,x='2012',y='Country Code',palette ="Accent")
plt.title("Bottom ten countries of total population of 2012", fontsize=10)
plt.xlabel('Total population',fontsize=10)
plt.xlabel('Country',fontsize=10)
plt.show()

# %% [markdown]
# ## Extraction of top ten countries with highest male population

# %%
male_population_data
# Out:
#            Series Code Country Code        2022        2021        2020  \
# 434  SP.POP.TOTL.MA.IN          AFG  20766442.0  20254878.0  19692301.0
# 435  SP.POP.TOTL.MA.IN          ALB   1384548.0   1404454.0   1419264.0
# 436  SP.POP.TOTL.MA.IN          DZA  22862237.0  22497244.0  22132899.0
# 437  SP.POP.TOTL.MA.IN          ASM     21873.0     22289.0     22921.0
# 438  SP.POP.TOTL.MA.IN          AND     40786.0     40361.0     39615.0
# ..                 ...          ...         ...         ...         ...
# 646  SP.POP.TOTL.MA.IN          VIR     49137.0     49510.0     49866.0
# 647  SP.POP.TOTL.MA.IN          PSE   2516444.0   2455361.0   2394860.0
# 648  SP.POP.TOTL.MA.IN          YEM  17023203.0  16668432.0  16320979.0
# 649  SP.POP.TOTL.MA.IN          ZMB   9877642.0   9609004.0   9338613.0
# 650  SP.POP.TOTL.MA.IN          ZWE   7705601.0   7543690.0   7385220.0
#
#            2019        2018        2017        2016        2015  ...  \
# ...

# %%
# filter data for male population
male_population_data = df[df['Series Code']=='SP.POP.TOTL.MA.IN']

#Sort data based on the male population of 2022
male_population_sorted = male_population_data.sort_values(by="2022" ,ascending= False)

#Get the top 10 countries with highest male popultaion for 2022
top_ten_male_sorted = male_population_sorted.head(10)
top_ten_male_sorted = top_ten_male_sorted[["Series Code", "Country Code", "2022"]]
print("Top Ten countries with highest male population")
print(top_ten_male_sorted)
# Out:
# Top Ten countries with highest male population
#            Series Code Country Code         2022
# 523  SP.POP.TOTL.MA.IN          IND  731180498.0
# 475  SP.POP.TOTL.MA.IN          CHN  720646499.0
# 640  SP.POP.TOTL.MA.IN          USA  165021339.0
# 524  SP.POP.TOTL.MA.IN          IDN  138703277.0
# 583  SP.POP.TOTL.MA.IN          PAK  118960880.0
# 578  SP.POP.TOTL.MA.IN          NGA  110448136.0
# 460  SP.POP.TOTL.MA.IN          BRA  105733027.0
# 449  SP.POP.TOTL.MA.IN          BGD   84859213.0
# 595  SP.POP.TOTL.MA.IN          RUS   66670833.0
# 561  SP.POP.TOTL.MA.IN          MEX   62194954.0

# %%
#Filter data for female population
female_population_data = df[df["Series Code"]=="SP.POP.TOTL.FE.IN"]

#sort data based on female population for the year 2022
female_population_sorted = female_population_data.sort_values(by="2022", ascending=False)

#Filter out the top ten countries with highest female population
female_top_ten_countries = female_population_sorted.head(10)
female_top_ten_countries = female_top_ten_countries[["Series Code", "Country Code", "2022"]]
print("Top 10 countries with highest female population")
print(female_top_ten_countries)
# Out:
# Top 10 countries with highest female population
#            Series Code Country Code         2022
# 258  SP.POP.TOTL.FE.IN          CHN  691528501.0
# 306  SP.POP.TOTL.FE.IN          IND  685992675.0
# 423  SP.POP.TOTL.FE.IN          USA  168266219.0
# 307  SP.POP.TOTL.FE.IN          IDN  136798063.0
# 366  SP.POP.TOTL.FE.IN          PAK  116863982.0
# 243  SP.POP.TOTL.FE.IN          BRA  109580471.0
# 361  SP.POP.TOTL.FE.IN          NGA  108093075.0
# 232  SP.POP.TOTL.FE.IN          BGD   86327159.0
# 378  SP.POP.TOTL.FE.IN          RUS   76884903.0
# 344  SP.POP.TOTL.FE.IN          MEX   65309171.0

# %% [markdown]
# ## Top ten countries with highest male and female population in 2022

# %%
# create a bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(data=top_ten_male_sorted,x='2022',y='Country Code',palette ="PuBu")
plt.title("Top ten countries with highest male population", fontsize=10)
plt.xlabel('Male population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(data=female_top_ten_countries,x='2022',y='Country Code',palette ="PuBu")
plt.title("Top ten countries with highest female population", fontsize=10)
plt.xlabel('Female population',fontsize=10)
plt.ylabel('Country',fontsize=10)
plt.show()

# %% [markdown]
# # Stacked Bar plot

# %% [markdown]
# ## Top 10 countries with male and female population

# %%
# merge male and female data on the country code
merge_data = pd.merge(male_population_data,female_population_data,on="Country Code",suffixes=("_male","_female"))

# %%
#merged data
# calculate the population of each country (male+female)
merge_data["Total population"] = merge_data["2022_male"]+merge_data["2022_female"]

# %%
merge_data.head(10)
# Out:
#     Series Code_male Country Code   2022_male   2021_male   2020_male  \
# 0  SP.POP.TOTL.MA.IN          AFG  20766442.0  20254878.0  19692301.0
# 1  SP.POP.TOTL.MA.IN          ALB   1384548.0   1404454.0   1419264.0
# 2  SP.POP.TOTL.MA.IN          DZA  22862237.0  22497244.0  22132899.0
# 3  SP.POP.TOTL.MA.IN          ASM     21873.0     22289.0     22921.0
# 4  SP.POP.TOTL.MA.IN          AND     40786.0     40361.0     39615.0
# 5  SP.POP.TOTL.MA.IN          AGO  17590767.0  17051491.0  16517497.0
# 6  SP.POP.TOTL.MA.IN          ATG     44782.0     44511.0     44236.0
# 7  SP.POP.TOTL.MA.IN          ARG  22889298.0  22678199.0  22465694.0
# 8  SP.POP.TOTL.MA.IN          ARM   1250079.0   1256498.0   1265512.0
# 9  SP.POP.TOTL.MA.IN          ABW     50173.0     50207.0     50211.0
#
#     2019_male   2018_male   2017_male   2016_male   2015_male  ...  \
# 0  19090409.0  18549862.0  18028696.0  17520861.0  17071446.0  ...
# ...

# %%
#sort data based on total population in descending order
sorted_data = merge_data.sort_values(by="Total population", ascending = False)

# %% [markdown]
# ## Select the top 10 countries with highest total population

# %%
top_10_countries = sorted_data.head(10)

# %%
#create the stacked bar plot
plt.figure(figsize=(12,6))
sns.barplot(data=top_10_countries,x="Country Code",y="2022_female",color="blue",label="female population")
sns.barplot(data=top_10_countries,x="Country Code",y="2022_male",bottom=top_10_countries["2022_female"],color="red",label="male population")
plt.xlabel("Country",fontsize=15)
plt.ylabel("Population",fontsize=15)
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bottom 10 countries with male and female population (2022)

# %%
#Select the bottom 10 countries with highest male and female population
bottom_10_countries = sorted_data.tail(10)

# %%
bottom_10_countries
# Out:
#       Series Code_male Country Code  2022_male  2021_male  2020_male  \
# 124  SP.POP.TOTL.MA.IN          MHL    21223.0    21483.0    22190.0
# 114  SP.POP.TOTL.MA.IN          LIE    19502.0    19354.0    19223.0
# 130  SP.POP.TOTL.MA.IN          MCO    17872.0    17982.0    18095.0
# 164  SP.POP.TOTL.MA.IN          SMR    16380.0    16419.0    16563.0
# 75   SP.POP.TOTL.MA.IN          GIB    16308.0    16317.0    16337.0
# 183  SP.POP.TOTL.MA.IN          MAF    15111.0    15188.0    15477.0
# 27   SP.POP.TOTL.MA.IN          VGB    15062.0    14976.0    14900.0
# 150  SP.POP.TOTL.MA.IN          PLW     9376.0     9380.0     9377.0
# 137  SP.POP.TOTL.MA.IN          NRU     6435.0     6361.0     6266.0
# 201  SP.POP.TOTL.MA.IN          TUV     5799.0     5755.0     5702.0
#
#      2019_male  2018_male  2017_male  2016_male  2015_male  ...  2009_female  \
# 124    22874.0    23529.0    24146.0    24738.0    25299.0  ...      26162.0
# ...

# %%
#create the stacked bar plot
plt.figure(figsize=(12,6))
sns.barplot(data=bottom_10_countries,x="Country Code",y="2022_female",color="yellow",label="female population")
sns.barplot(data=bottom_10_countries,x="Country Code",y="2022_male",bottom=bottom_10_countries["2022_female"],color="green",label="male population")
plt.xlabel("Country",fontsize=15)
plt.ylabel("Population",fontsize=15)
plt.legend()
plt.xticks(rotation=45)
plt.show()
